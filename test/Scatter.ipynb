# %%
import matplotlib.pyplot as plt
import json

forEachJson = json.load(open("./$forEach-cpu.json", "r"))
forOfJson = json.load(open("./$forOf-cpu.json", "r"))
forJson = json.load(open("./$for-cpu.json", "r"))
whileJson = json.load(open("./$while-cpu.json", "r"))

forEachx = [i for i, key in enumerate(forEachJson)]
forEachy = [key for i, key in enumerate(forEachJson)]

forOfx = [i for i, key in enumerate(forOfJson)]
forOfy = [key for i, key in enumerate(forOfJson)]

forx = [i for i, key in enumerate(forJson)]
fory = [key for i, key in enumerate(forJson)]

whilex = [i for i, key in enumerate(whileJson)]
whiley = [key for i, key in enumerate(whileJson)]

plt.figure(figsize=(30,20))



plt.scatter(whilex,whiley,None,'#b134eb')
plt.scatter(forx,fory,None,'#34a4eb')
plt.scatter(forEachx,forEachy,None,'#eb4034')
plt.scatter(forOfx,forOfy,None,'#3deb34')

plt.show()
